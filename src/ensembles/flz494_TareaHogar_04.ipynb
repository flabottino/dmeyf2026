# %% [markdown]
# <a href="https://colab.research.google.com/github/flabottino/dmeyf2026/blob/desktop-jr/flz494_TareaHogar_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarea para el Hogar 04

# %% [markdown]
# ##  1. Overfitting the Public Leaderboard

# %% [markdown]
# Leer  https://medium.com/hmif-itb/overfitting-the-leaderboard-da25172ac62e
# ( 8 minutos )

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion sw Hiperparámetros lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# * https://machinelearningmastery.com/light-gradient-boosted-machine-lightgbm-ensemble/
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
# %%shell
#
# mkdir -p "/content/.drive/My Drive/dmeyf"
# mkdir -p "/content/buckets"
# ln -sfn "/content/.drive/My Drive/dmeyf"   /content/buckets/b1
#
# mkdir -p ~/.kaggle
# cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
# chmod 600 ~/.kaggle/kaggle.json
#
#
# mkdir -p /content/buckets/b1/exp
# mkdir -p /content/buckets/b1/datasets
# mkdir -p /content/datasets
#
#
# # defino funcion descargar()
# descargar() {
#   carpeta_destino="/content/buckets/b1/datasets/"
#   url_origen="https://storage.googleapis.com/open-courses/utn2026-b40a/"
#   archivo="$1"
#
#   if ! test -f "$carpeta_destino""$archivo"; then
#     wget  "$url_origen""$archivo"  -O "$carpeta_destino""$archivo"
#   fi
#
#   if ! test -f  "/content/datasets/""$archivo"; then
#     cp  "$carpeta_destino""$archivo"  "/content/datasets/""$archivo"
#   fi;
# }
#
# # hago la descarga efectiva, llamando a descargar()
# descargar  "dataset_pequeno.csv"

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sun Aug 30 09:26:59 PM 2026"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  675438 36.1 1473300    78.7 1473300  78.7
# Vcells 1251978  9.6 8388608    64.0 1978711  15.1

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")
# Out:
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following object is masked from ‘package:base’:
#
#     %notin%
#
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘primes’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘rlist’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘XML’
#
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 59402

PARAM$semilla_primigenia <- 100019

# %%
PARAM$kaggle$competencia <- "utn-2026-inicial"
PARAM$kaggle$cortes <- seq(9000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations = 2000,
  early_stopping_rounds = 50,
  learning_rate= 0.10,  # >=0
  feature_fraction= 1.0, # 0 < ff <= 1.0
  num_leaves= 32, # integer >= 2
  min_data_in_leaf= 20 # integer >= 0
)

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83585
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion del Grid Search

# %%
# En el argumento x llegan los parmaetros de LightGBM
#  devuelve la AUC en cross validation del modelo entrenado

Estimar_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # Inyectar las semillas específicas en la lista
  param_completo$seed <- x$seed
  param_completo$feature_fraction_seed <- x$seed
  param_completo$bagging_seed <- x$seed


  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo,
    early_stopping_rounds = 50
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y  "),
    toString(x),
    " AUC ", AUC
  )

  return(AUC)
}

# %%
file.remove("tb_grid_serach_02.txt")
# Out:
# Warning message in file.remove("tb_grid_serach_01.txt"):
# “cannot remove file 'tb_grid_serach_01.txt', reason 'No such file or directory'”
# [1] FALSE

# %%
archivo_grid <- "tb_grid_serach_02.txt"

# 1. Grilla con los 5 parámetros deseados

tb_nueva <- CJ(
  learning_rate    = c(0.003, 0.005, 0.01),  # <-- Valores más bajos
  feature_fraction = c(0.4, 0.6, 0.8),
  min_data_in_leaf = c(50, 100, 300),
  num_leaves       = c(15, 31, 63),
  seed             = c(100019, 250007, 500009, 750011, 999979)
)

# 2. Chequear si ya hay un archivo de guardado previo en Google Drive
if (file.exists(archivo_grid)) {
  tb_ya_calculados <- fread(archivo_grid)

  # Anti-join sintaxis nativa de data.table:
  tb_nueva <- tb_nueva[!tb_ya_calculados, on = c("learning_rate", "feature_fraction", "min_data_in_leaf", "num_leaves", "seed")]

  cat("Reanudando Grid Search. Combinaciones pendientes por procesar:", nrow(tb_nueva), "\n")
} else {
  cat("Iniciando Grid Search desde cero. Combinaciones totales a calcular:", nrow(tb_nueva), "\n")
}
# Out:
# Iniciando Grid Search desde cero. Combinaciones totales a calcular: 405

# %%
# lo que sigue a continuacion es una forma alternativa a los loops anidados
# creo una tabla con el producto cartesiano de los vectores
#tb_nueva <- CJ(

#  learning_rate= c(0.01, 0.05, 0.1),
#  feature_fraction = c(0.4, 0.6, 0.8),
#  min_data_in_leaf = c(20, 100, 500),
#  num_leaves= c(15, 31, 63),
#  seed = c(100019,250007,500009,750011,999979)
#)

# %%
# veo que tiene la tabla antes de procesar
tb_nueva
# Out:
#     learning_rate feature_fraction min_data_in_leaf num_leaves seed
# 1   0.01          0.4               20              15         100019
# 2   0.01          0.4               20              15         250007
# 3   0.01          0.4               20              15         500009
# 4   0.01          0.4               20              15         750011
# 5   0.01          0.4               20              15         999979
# 6   0.01          0.4               20              31         100019
# 7   0.01          0.4               20              31         250007
# 8   0.01          0.4               20              31         500009
# 9   0.01          0.4               20              31         750011
# 10  0.01          0.4               20              31         999979
# 11  0.01          0.4               20              63         100019
# 12  0.01          0.4               20              63         250007
# 13  0.01          0.4               20              63         500009
# 14  0.01          0.4               20              63         750011
# 15  0.01          0.4               20              63         999979
# 16  0.01          0.4              100              15         100019
# 17  0.01          0.4              100              15         250007
# 18  0.01          0.4              100              15         500009
# 19  0.01          0.4              100              15         750011
# 20  0.01          0.4              100              15         999979
# 21  0.01          0.4              100              31         100019
# 22  0.01          0.4              100              31         250007
# 23  0.01          0.4              100              31         500009
# 24  0.01          0.4              100              31         750011
# 25  0.01          0.4              100              31         999979
# 26  0.01          0.4              100              63         100019
# 27  0.01          0.4              100              63         250007
# 28  0.01          0.4              100              63         500009
# 29  0.01          0.4              100              63         750011
# 30  0.01          0.4              100              63         999979
# ⋮   ⋮             ⋮                ⋮                ⋮          ⋮
# 376 0.1           0.8              100              15         100019
# 377 0.1           0.8              100              15         250007
# 378 0.1           0.8              100              15         500009
# 379 0.1           0.8              100              15         750011
# 380 0.1           0.8              100              15         999979
# 381 0.1           0.8              100              31         100019
# 382 0.1           0.8              100              31         250007
# 383 0.1           0.8              100              31         500009
# 384 0.1           0.8              100              31         750011
# 385 0.1           0.8              100              31         999979
# 386 0.1           0.8              100              63         100019
# 387 0.1           0.8              100              63         250007
# 388 0.1           0.8              100              63         500009
# 389 0.1           0.8              100              63         750011
# 390 0.1           0.8              100              63         999979
# 391 0.1           0.8              500              15         100019
# 392 0.1           0.8              500              15         250007
# 393 0.1           0.8              500              15         500009
# 394 0.1           0.8              500              15         750011
# 395 0.1           0.8              500              15         999979
# 396 0.1           0.8              500              31         100019
# 397 0.1           0.8              500              31         250007
# 398 0.1           0.8              500              31         500009
# 399 0.1           0.8              500              31         750011
# 400 0.1           0.8              500              31         999979
# 401 0.1           0.8              500              63         100019
# 402 0.1           0.8              500              63         250007
# 403 0.1           0.8              500              63         500009
# 404 0.1           0.8              500              63         750011
# 405 0.1           0.8              500              63         999979

# %%
# Función auxiliar que procesa una combinación y escribe en disco inmediatamente
evaluar_y_guardar <- function(x) {
  auc_calculado <- Estimar_AUC_lightgbm(x)

  fila_res <- as.data.table(x)
  fila_res[, AUC := auc_calculado]

  # Guardado inmediato fila a fila (append = TRUE si ya existe el archivo)
  fwrite(
    fila_res,
    file = archivo_grid,
    sep = "\t",
    append = file.exists(archivo_grid),
    col.names = !file.exists(archivo_grid)
  )

  return(auc_calculado)
}

# Ejecutar el cálculo solo sobre las filas pendientes
if (nrow(tb_nueva) > 0) {
  tb_nueva[, AUC := evaluar_y_guardar(list(.SD)), by = 1:nrow(tb_nueva)]
}

# Leer la tabla acumulada completa con los resultados consolidados
tb_nueva <- fread(archivo_grid)

# Seleccionar el mejor hiperparámetro
setorder(tb_nueva, -AUC)
PARAM$out$lgbm$AUC <- tb_nueva[1, AUC]
PARAM$out$lgbm$mejores_hiperparametros <- as.list(tb_nueva[1])
PARAM$out$lgbm$mejores_hiperparametros$AUC <- NULL
PARAM$out$lgbm$mejores_hiperparametros

write_yaml(PARAM, file = "PARAM.yml")
# Out:
# Sun Aug 30 09:38:06 PM 2026  list(learning_rate = 0.01, feature_fraction = 0.4, min_data_in_leaf = 20, num_leaves = 15, seed = 100019) AUC 0.927289031198014
#
# Sun Aug 30 09:38:29 PM 2026  list(learning_rate = 0.01, feature_fraction = 0.4, min_data_in_leaf = 20, num_leaves = 15, seed = 250007) AUC 0.926184460430786
#
# Sun Aug 30 09:38:47 PM 2026  list(learning_rate = 0.01, feature_fraction = 0.4, min_data_in_leaf = 20, num_leaves = 15, seed = 500009) AUC 0.925274219525532
#
# Sun Aug 30 09:39:05 PM 2026  list(learning_rate = 0.01, feature_fraction = 0.4, min_data_in_leaf = 20, num_leaves = 15, seed = 750011) AUC 0.92663205421232
#
# Sun Aug 30 09:39:24 PM 2026  list(learning_rate = 0.01, feature_fraction = 0.4, min_data_in_leaf = 20, num_leaves = 15, seed = 999979) AUC 0.925536731767453
#
# Sun Aug 30 09:39:43 PM 2026  list(learning_rate = 0.01, feature_fraction = 0.4, min_data_in_leaf = 20, num_leaves = 31, seed = 100019) AUC 0.927397685930413
#
# Sun Aug 30 09:40:11 PM 2026  list(learning_rate = 0.01, feature_fraction = 0.4, min_data_in_leaf = 20, num_leaves = 31, seed = 250007) AUC 0.927494269272912
#
# Sun Aug 30 09:40:32 PM 2026  list(learning_rate = 0.01, feature_fraction = 0.4, min_data_in_leaf = 20, num_leaves = 31, seed = 500009) AUC 0.92693165655446
#
# Sun Aug 30 09:40:54 PM 2026  list(learning_rate = 0.01, feature_fraction = 0.4, min_data_in_leaf = 20, num_leaves = 31, seed = 750011) AUC 0.926710876717878
#
# Sun Aug 30 09:41:11 PM 2026  list(learning_rate = 0.01, feature_fraction = 0.4, min_data_in_leaf = 20, num_leaves = 31, seed = 999979) AUC 0.926296613463978
#
# Sun Aug 30 09:41:28 PM 2026  list(learning_rate = 0.01, feature_fraction = 0.4, min_data_in_leaf = 20, num_leaves = 63, seed = 100019) AUC 0
PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 20, num_leaves = 63, seed = 750011) AUC 0.924564600635323
#
# Sun Aug 30 11:44:30 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 20, num_leaves = 63, seed = 999979) AUC 0.926718594481574
#
# Sun Aug 30 11:44:49 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 100, num_leaves = 15, seed = 100019) AUC 0.926104589971755
#
# Sun Aug 30 11:45:08 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 100, num_leaves = 15, seed = 250007) AUC 0.926565406481124
#
# Sun Aug 30 11:45:26 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 100, num_leaves = 15, seed = 500009) AUC 0.926886278697429
#
# Sun Aug 30 11:45:44 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 100, num_leaves = 15, seed = 750011) AUC 0.926490928304439
#
# Sun Aug 30 11:46:06 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 100, num_leaves = 15, seed = 999979) AUC 0.928472784757072
#
# Sun Aug 30 11:46:25 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 100, num_leaves = 31, seed = 100019) AUC 0.928040959205786
#
# Sun Aug 30 11:46:48 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 100, num_leaves = 31, seed = 250007) AUC 0.9259671855583
#
# Sun Aug 30 11:47:06 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 100, num_leaves = 31, seed = 500009) AUC 0.926363517937927
#
# Sun Aug 30 11:47:22 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 100, num_leaves = 31, seed = 750011) AUC 0.926203130706986
#
# Sun Aug 30 11:47:48 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 100, num_leaves = 31, seed = 999979) AUC 0.926623434523943
#
# Sun Aug 30 11:48:13 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 100, num_leaves = 63, seed = 100019) AUC 0.926975734988502
#
# Sun Aug 30 11:48:34 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 100, num_leaves = 63, seed = 250007) AUC 0.925466210622201
#
# Sun Aug 30 11:48:56 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 100, num_leaves = 63, seed = 500009) AUC 0.926722107039323
#
# Sun Aug 30 11:49:13 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 100, num_leaves = 63, seed = 750011) AUC 0.926421780282947
#
# Sun Aug 30 11:49:30 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 100, num_leaves = 63, seed = 999979) AUC 0.926627905437685
#
# Sun Aug 30 11:49:51 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 500, num_leaves = 15, seed = 100019) AUC 0.92628017709389
#
# Sun Aug 30 11:50:11 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 500, num_leaves = 15, seed = 250007) AUC 0.928168765074751
#
# Sun Aug 30 11:50:28 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 500, num_leaves = 15, seed = 500009) AUC 0.925189178068569
#
# Sun Aug 30 11:50:54 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 500, num_leaves = 15, seed = 750011) AUC 0.926239409929172
#
# Sun Aug 30 11:51:12 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 500, num_leaves = 15, seed = 999979) AUC 0.924758916945377
#
# Sun Aug 30 11:51:35 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 500, num_leaves = 31, seed = 100019) AUC 0.925376430829269
#
# Sun Aug 30 11:51:53 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 500, num_leaves = 31, seed = 250007) AUC 0.92749498255114
#
# Sun Aug 30 11:52:12 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 500, num_leaves = 31, seed = 500009) AUC 0.924989801576387
#
# Sun Aug 30 11:52:36 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 500, num_leaves = 31, seed = 750011) AUC 0.926881809895119
#
# Sun Aug 30 11:52:56 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 500, num_leaves = 31, seed = 999979) AUC 0.926364329896803
#
# Sun Aug 30 11:53:19 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 500, num_leaves = 63, seed = 100019) AUC 0.927001647034157
#
# Sun Aug 30 11:53:36 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 500, num_leaves = 63, seed = 250007) AUC 0.927201152183616
#
# Sun Aug 30 11:54:00 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 500, num_leaves = 63, seed = 500009) AUC 0.928521546084869
#
# Sun Aug 30 11:54:22 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 500, num_leaves = 63, seed = 750011) AUC 0.926514180581925
#
# Sun Aug 30 11:54:47 PM 2026  list(learning_rate = 0.1, feature_fraction = 0.8, min_data_in_leaf = 500, num_leaves = 63, seed = 999979) AUC 0.926281911900596
# $learning_rate
# [1] 0.01
#
# $feature_fraction
# [1] 0.6
#
# $min_data_in_leaf
# [1] 100
#
# $num_leaves
# [1] 31
#
# $seed
# [1] 999979

# %%
# registro a registro calculo la AUC
#tb_nueva[, AUC:= Estimar_AUC_lightgbm( list(.SD)),
#  by=1:nrow(tb_nueva) ]

# %%
# veo que tiene la tabla DESPUES de procesar
#tb_nueva

# %%
#fwrite( tb_nueva,
#  file= "tb_grid_serach_01.txt",
#  sep="\t",
#  append= TRUE
#)

# %%
#setorder( tb_nueva, -AUC)
#PARAM$out$lgbm$AUC <- tb_nueva[1, AUC]
#PARAM$out$lgbm$mejores_hiperparametros <- as.list( tb_nueva[1] )
#PARAM$out$lgbm$mejores_hiperparametros$AUC <- NULL
#PARAM$out$lgbm$mejores_hiperparametros

# %%
#write_yaml( PARAM, file="PARAM.yml")

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización de hiperparametros

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 999979
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0
#
# $lambda_l2
# [1] 0
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 1
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 2000
#
# $early_stopping_rounds
# [1] 50
#
# $learning_rate
# [1] 0.01
#
# $feature_fraction
# [1] 0.6
#
# $num_leaves
# [1] 31
#
# $min_data_in_leaf
# [1] 100

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

# %%
# Remuevo early_stopping_rounds ya que no hay conjunto de validación en el entrenamiento final
param_normalizado$early_stopping_rounds <- NULL

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
#setorder(tb_prediccion, -prob)

#dir.create("kaggle")


#for (envios in PARAM$kaggle$cortes) {

#  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
#  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

 # archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  #fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
  #  file= archivo_kaggle,
 #   sep= ","
 # )

 # # subida a Kaggle, armo la linea de comando
 # comando <- "kaggle competitions submit"
 # competencia <- paste("-c", PARAM$kaggle$competencia)
 # arch <- paste( "-f", archivo_kaggle)

 # mensaje <- paste0("-m 'envios=", envios,
 # "  semilla=", PARAM$semilla_primigenia,
 #   "'" )

 # linea <- paste( comando, competencia, arch, mensaje)

#  salida <- system(linea, intern=TRUE) # el submit a Kaggle
#  cat(salida, "\n")
#  Sys.sleep(45)
#}

# %%
setorder(tb_prediccion, -prob)

dir.create("kaggle", showWarnings = FALSE)

# Archivo de control de subidas a Kaggle
archivo_log_kaggle <- "./kaggle/subidas_completadas.txt"

if (file.exists(archivo_log_kaggle)) {
  envios_hechos <- fread(archivo_log_kaggle)$envios
} else {
  envios_hechos <- integer(0)
}

for (envios in PARAM$kaggle$cortes) {

  # Si este corte ya fue enviado en una corrida previa, lo saltea
  if (envios %in% envios_hechos) {
    cat("El corte de envíos", envios, "ya fue subido a Kaggle anteriormente. Salteando...\n")
    next
  }

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marco los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file = archivo_kaggle,
    sep = ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste("-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
    "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste(comando, competencia, arch, mensaje)

  salida <- system(linea, intern = TRUE) # el submit a Kaggle
  cat(salida, "\n")

  # Registro el envío exitoso para no reejecutarlo si el notebook se desconecta
  fwrite(data.table(envios = envios),
         file = archivo_log_kaggle,
         append = file.exists(archivo_log_kaggle))

  Sys.sleep(45)
}
# Out:
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 Inicial
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 Inicial
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 Inicial
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 Inicial
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 Inicial
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 Inicial
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 Inicial

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
cat(readLines("PARAM.yml"), sep = "\n")
# Out:
# experimento: 59401.0
# semilla_primigenia: 100019.0
# kaggle:
#   competencia: utn-2026-inicial
#   cortes:
#   - 9000.0
#   - 9500.0
#   - 10000.0
#   - 10500.0
#   - 11000.0
#   - 11500.0
#   - 12000.0
# trainingstrategy:
#   undersampling: 0.5
# hyperparametertuning:
#   xval_folds: 5.0
# lgbm:
#   param_fijos:
#     boosting: gbdt
#     objective: binary
#     metric: auc
#     first_metric_only: no
#     boost_from_average: yes
#     feature_pre_filter: no
#     force_row_wise: yes
#     verbosity: -100.0
#     seed: 100019.0
#     max_depth: -1
#     min_gain_to_split: 0.0
#     min_sum_hessian_in_leaf: 0.001
#     lambda_l1: 0.0
#     lambda_l2: 0.0
#     max_bin: 31
#     bagging_fraction: 1.0
#     pos_bagging_fraction: 1.0
#     neg_bagging_fraction: 1.0
#     is_unbalance: no
#     scale_pos_weight: 1.0
#     drop_rate: 0.1
#     max_drop: 50.0
#     skip_drop: 0.5
#     extra_trees: no
#     num_iterations: 2000.0
#     early_stopping_rounds: 50.0
#     learning_rate: 0.1
#     feature_fraction: 1.0
#     num_leaves: 32.0
#     min_data_in_leaf: 20.0
# out:
#   lgbm:
#     AUC: 0.9286032
#     mejores_hiperparametros:
#       learning_rate: 0.01
#       feature_fraction: 0.6
#       min_data_in_leaf: 100
#       num_leaves: 31
#       seed: 999979

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Mon Aug 31 12:10:11 AM 2026"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar-04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla

# %% [markdown]
# Seguramente usted realice varias corridas de este script con distintos conjuntos de hiperparámetros, siempre cambiandole el nombre al script  y también cambiando el nombre del experimento,  deberá TODAS esas corridas en distintas lineas de la  Google Sheet Colaborativa, hoja **TareaHogar-04**

# %% [markdown]
# Siéntase libre de agregar columnas a la hoja **TareaHogar-04**  en caso de ser necesario.
